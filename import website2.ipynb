# %%
import pandas as pd
# turns off warning messsages
import warnings
warnings.filterwarnings('ignore')

website = 'http://www.admissions.cn/ahu/en2.html'
datalist = pd.read_html(website)
datalist[0]
# Out:
#                                                    0   \
# 0                        QUALIFICATIONS FOR ADMISSION
# 1                        BACHELOR’S  DEGREE  STUDENTS
# 2                        BACHELOR’S  DEGREE  STUDENTS
# 3                                 DOCTORATE  STUDENTS
# 4                                 DOCTORATE  STUDENTS
# 5   HSK requirements: Grade 6 for students to take...
# 6   Applicants of the above categories, who do not...
# 7                           CHINESE LANGUAGE STUDENTS
# 8                           CHINESE LANGUAGE STUDENTS
# 9   DURATION AND COMPLETION OF STUDIES, AWARDING O...
# 10                         BACHELOR’S DEGREE STUDENTS
# 11                           MASTER’S DEGREE STUDENTS
# 12                                 DOCTORATE STUDENTS
# 13                        STUDENTS OF GENERAL COURSES
# 14                       STUDENTS OF ADVANCED COURSES
# 15              STUDENTS FOR CHINESE LANGUAGE STUDIES
# ...
